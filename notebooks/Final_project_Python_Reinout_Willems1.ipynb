# %% [markdown]
# **Introduction: (5 pt)**
# Formulate a research question that allows for explorations and comparisons. For example: How have vaccinations influenced hospitalizations in different European Union (EU) countries? You can divide this in two steps: 1. How vaccinations have influenced hospitalizations in a country (i.e Netherlands or Italy); 2. How does one country compare to the other countries in the EU? *(5 pt)*

# %% [markdown]
# RQ of this project: What is the relation between schooling and the vaccination rate in different Asian countries of the ASEAN Regional Forum (ARF)?
# 1. What is the relation between schooling and the vaccination rate in some Asian ARF countries?
# 2. How does it compare to other Asian ARF countries?

# %% [markdown]
# List of ARF countries: Australia, Bangladesh, Brunei Darussalam, Cambodia, Canada, China, Democratic People’s Republic of Korea, European Union, India, Indonesia, Japan, Lao PDR, Malaysia, Mongolia, Myanmar, New Zealand, Pakistan, Papua New Guinea, Philippines, Republic of Korea, Russia, Singapore, Sri Lanka, Thailand, Timor-Leste, United States, and Viet Nam.

# %% [markdown]
# List of Asian ARF countries: Bangladesh, Brunei Darussalam (Brunei), Cambodia, China, Democratic People’s Republic of Korea (North Korea), India, Indonesia, Japan, Lao PDR (Laos), Malaysia, Mongolia, Myanmar, Pakistan, Philippines, Republic of Korea (South Korea), Russia, Singapore, Sri Lanka, Thailand, Timor-Leste, and Viet Nam

# %% [markdown]
# **Data preparation: (20 pt)**
# Load the dataset using this link for health factors dataLinks to an external site.. Copy the link and load it as you did in the practicals. *(5 pt)*
# Select rows and columns relevant to your research question. *(15 pt)*

# %%
#Load the dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import altair as alt
import ipywidgets as widgets
from ipywidgets import interact

FactorHealth = pd.read_csv('https://raw.githubusercontent.com/NHameleers/dtz2025-datasets/master/CountryHealthFactors.csv')
FactorHealth.head(n=17)
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 0   Afghanistan  2015  Developing              65.0            263.0
# 1   Afghanistan  2014  Developing              59.9            271.0
# 2   Afghanistan  2013  Developing              59.9            268.0
# 3   Afghanistan  2012  Developing              59.5            272.0
# 4   Afghanistan  2011  Developing              59.2            275.0
# 5   Afghanistan  2010  Developing              58.8            279.0
# 6   Afghanistan  2009  Developing              58.6            281.0
# 7   Afghanistan  2008  Developing              58.1            287.0
# 8   Afghanistan  2007  Developing              57.5            295.0
# 9   Afghanistan  2006  Developing              57.3            295.0
# 10  Afghanistan  2005  Developing              57.3            291.0
# 11  Afghanistan  2004  Developing              57.0            293.0
# 12  Afghanistan  2003  Developing              56.7            295.0
# ...

# %%
FactorHealth = FactorHealth.rename(columns=str.strip)

# %%
print(FactorHealth.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
FactorHealth['Average Vaccination Rate'] = (FactorHealth['Hepatitis B'] + FactorHealth['Polio'] + FactorHealth['Diphtheria']) / 3
FactorHealth
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
#Select rows and columns for RQ
Asian_ARFcountries = ['Bangladesh', 'Brunei Darussalam', 'China', 'Cambodia', "Democratic People's Republic of Korea", 'India', 'Indonesia', 'Japan', "Lao People's Democratic Republic", 'Malaysia', 'Mongolia', 'Myanmar', 'Pakistan',
'Philippines', 'Republic of Korea', 'Russian Federation', 'Singapore', 'Sri Lanka', 'Thailand', 'Timor-Leste', 'Viet Nam']

ResearchColumns = ['Country', 'Year', 'Hepatitis B', 'Polio', 'Diphtheria', 'Schooling', 'Average Vaccination Rate']

FactorHealth1 = FactorHealth[FactorHealth['Country'].isin(Asian_ARFcountries)][ResearchColumns]
FactorHealth1
# Out:
#          Country  Year  Hepatitis B  Polio  Diphtheria  Schooling  \
# 192   Bangladesh  2015         97.0   97.0        97.0       10.2
# 193   Bangladesh  2014         97.0   97.0        97.0       10.0
# 194   Bangladesh  2013         96.0   96.0        96.0       10.0
# 195   Bangladesh  2012         94.0   94.0        94.0        9.9
# 196   Bangladesh  2011         96.0   96.0        96.0        9.4
# ...          ...   ...          ...    ...         ...        ...
# 2885    Viet Nam  2004         94.0   96.0        96.0       11.0
# 2886    Viet Nam  2003         78.0   96.0        99.0       10.9
# 2887    Viet Nam  2002          NaN   92.0        75.0       10.7
# 2888    Viet Nam  2001          NaN   96.0        96.0       10.6
# 2889    Viet Nam  2000          NaN   96.0        96.0       10.4
#
#       Average Vaccination Rate
# 192                  97.000000
# 193                  97.000000
# 194                  96.000000
# 195                  94.000000
# ...

# %% [markdown]
# **Explore and clean the data by: (20 pt)**
# Exploring data using descriptive statistics or visualisations to get to know the dataset and spot possible issues (such as outliers or typos)*(10 pt)*
# Identify and report issues with missing data. *(5 pt)*
# Resolve issues with missing data and clean other data inconsistencies. Report also if you found no issues and how you verified this. *(5 pt)*[linktekst](https://)

# %%
#Exploring data using descriptive statistics or visualisations to get to know the dataset and spot possible issues (such as outliers or typos)
#Identify and report issues with missing data
FactorHealth1.describe()
#Lots of missing values at Hepatitis B, and the same amount of missing values at the average vaccination rate
#32 missing values from countries when it comes to schooling, since every country has noted data for 16 different years, it could be that 2 countries miss all their values in schooling
#Minimum values of Vaccinations and schooling significantly differ from the average value
# Out:
#               Year  Hepatitis B       Polio  Diphtheria   Schooling  \
# count   336.000000   280.000000  334.000000  334.000000  304.000000
# mean   2007.500000    81.878571   85.107784   85.532934   11.444079
# std       4.616647    24.493864   21.287544   18.273460    2.443250
# min    2000.000000     4.000000    5.000000    5.000000    0.000000
# 25%    2003.750000    77.000000   81.000000   79.000000    9.875000
# 50%    2007.500000    94.000000   95.000000   94.000000   11.700000
# 75%    2011.250000    97.000000   98.000000   97.000000   13.225000
# max    2015.000000    99.000000   99.000000   99.000000   15.400000
#
#        Average Vaccination Rate
# count                280.000000
# mean                  85.158333
# std                   17.845523
# min                    8.000000
# 25%                   77.583333
# 50%                   94.333333
# 75%                   97.000000
# max                   99.000000

# %%
#Exploring data using descriptive statistics or visualisations to get to know the dataset and spot possible issues (such as outliers or typos)
#Identify and report issues with missing data
alt.Chart(FactorHealth1).mark_point().encode(
    x ='Schooling',
    y ='Hepatitis B',
    color= 'Country'
)
#Japan, North Korea and South Korea are missing from the file
#Few values below and around 10, decimal is probably placed wrongly
# Out:
# alt.Chart(...)

# %%
#Exploring data using descriptive statistics or visualisations to get to know the dataset and spot possible issues (such as outliers or typos)
#Identify and report issues with missing data
alt.Chart(FactorHealth1).mark_point().encode(
    x ='Schooling',
    y ='Polio',
    color = 'Country'
)

#North and South Korea missing
#Few values below 10 --> decimal probably wrongly placed
# Out:
# alt.Chart(...)

# %%
#Exploring data using descriptive statistics or visualisations to get to know the dataset and spot possible issues (such as outliers or typos)
#Identify and report issues with missing data
alt.Chart(FactorHealth1).mark_point().encode(
    x ='Schooling',
    y ='Diphtheria',
    color = 'Country'
)
#North Korea and South Korea are missing
#Few values below 10 --> decimal probably placed at the wrong point
# Out:
# alt.Chart(...)

# %%
#Exploring data using descriptive statistics or visualisations to get to know the dataset and spot possible issues (such as outliers or typos)
#Identify and report issues with missing data
alt.Chart(FactorHealth1).mark_point().encode(
    x ='Year',
    y ='Schooling',
    color = 'Country'
)
#North Korea and South Korea are missing
#Overall, the values are not wrong
# Out:
# alt.Chart(...)

# %%
FactorHealth1["Country"].unique()
#No typos in countries' names, so that doesn't have to be resolved
# Out:
# array(['Bangladesh', 'Brunei Darussalam', 'Cambodia', 'China',
#        "Democratic People's Republic of Korea", 'India', 'Indonesia',
#        'Japan', "Lao People's Democratic Republic", 'Malaysia',
#        'Mongolia', 'Myanmar', 'Pakistan', 'Philippines',
#        'Republic of Korea', 'Russian Federation', 'Singapore',
#        'Sri Lanka', 'Thailand', 'Timor-Leste', 'Viet Nam'], dtype=object)

# %%
#Resolve issues with missing data and clean other data inconsistencies. Report also if you found no issues and how you verified this.
FactorHealth2 = FactorHealth1[(FactorHealth1['Hepatitis B'] >= 12.0) & (FactorHealth1['Diphtheria'] >= 10.0) & (FactorHealth1['Polio'] >= 10.0) & (FactorHealth1['Schooling'] >= 2.0)]
FactorHealth2

#When checking the unique values (names) of countries, no typos were indicated, so there's no need to resolve that
# Out:
#          Country  Year  Hepatitis B  Polio  Diphtheria  Schooling  \
# 192   Bangladesh  2015         97.0   97.0        97.0       10.2
# 193   Bangladesh  2014         97.0   97.0        97.0       10.0
# 194   Bangladesh  2013         96.0   96.0        96.0       10.0
# 195   Bangladesh  2012         94.0   94.0        94.0        9.9
# 196   Bangladesh  2011         96.0   96.0        96.0        9.4
# ...          ...   ...          ...    ...         ...        ...
# 2882    Viet Nam  2007         67.0   92.0        92.0       11.4
# 2883    Viet Nam  2006         93.0   94.0        94.0       11.3
# 2884    Viet Nam  2005         94.0   94.0        95.0       11.1
# 2885    Viet Nam  2004         94.0   96.0        96.0       11.0
# 2886    Viet Nam  2003         78.0   96.0        99.0       10.9
#
#       Average Vaccination Rate
# 192                  97.000000
# 193                  97.000000
# 194                  96.000000
# 195                  94.000000
# ...

# %% [markdown]
# **Describe and visualise: (50 pt)**
# Provide a description of the population for the reader (e.g. countries or continents) relevant to your question using a table with descriptive statistics (i.e. means, medians, standard deviations) and where possible visualisation. *(15pt)*
# Make the report interactive: Create at least one interactive visualisation using input from the user. *(20pt)*
# Turn your interactive report into an application using GitHub, Voila and Binder.** *(15pt)*

# %%
#Description sample
FactorHealth2['Country'].value_counts()
# Out:
# Thailand                            16
# Singapore                           16
# Malaysia                            16
# Mongolia                            16
# Brunei Darussalam                   16
# Russian Federation                  15
# China                               14
# Viet Nam                            13
# Philippines                         13
# Sri Lanka                           13
# Indonesia                           12
# Bangladesh                          11
# Pakistan                            10
# Lao People's Democratic Republic     9
# Cambodia                             9
# Myanmar                              9
# Timor-Leste                          8
# India                                6
# Name: Country, dtype: int64

# %%
#Correlation of each country compared to other countries
from IPython.display import display

#create variable for options in dropdown
Countrychoice = FactorHealth2["Country"].unique()

#Create dropdown
DropdownCountries = widgets.Dropdown(
    options=Countrychoice,
    description='Select a country'
)

#Connect dropdown to correlation between Schooling and Average vaccination rate
def select_country(change):
  Country_selected = change['new']
  Data_countries = FactorHealth2[FactorHealth2['Country'] == Country_selected]
  CorrCountry = Data_countries[['Schooling', 'Average Vaccination Rate']].corr()
  display(CorrCountry)

#Connect function to dropdown
DropdownCountries.observe(select_country, names= 'value')

display(DropdownCountries)
# Out:
# Dropdown(description='Select a country', options=('Bangladesh', 'Brunei Darussalam', 'Cambodia', 'China', 'Ind…

# %%
#Correlation of each country compared to other countries
from ipywidgets import interact, fixed

def Country_data(Country, FactorHealth2):
  return FactorHealth2.loc[FactorHealth2['Country'] == Country]

def interact_visualization(Country, FactorHealth2):
  Visualization = Country_data(Country, FactorHealth2)
  ChartPoint = alt.Chart(Visualization).mark_point().encode(x = 'Schooling', y = 'Average Vaccination Rate')
  ChartTotal = ChartPoint + ChartPoint.transform_regression('Schooling', 'Average Vaccination Rate').mark_line()
  display(ChartTotal)

interact(interact_visualization,
         Country=FactorHealth2['Country'].unique(),
         FactorHealth2=fixed(FactorHealth2));
# Out:
# interactive(children=(Dropdown(description='Country', options=('Bangladesh', 'Brunei Darussalam', 'Cambodia', …

# %%
#Comparing the mean average vaccination rate of every country
FactorHealth3 = FactorHealth2.groupby('Country')['Schooling', 'Average Vaccination Rate'].mean()
chart = alt.Chart(FactorHealth3).mark_point().encode(
    x = 'Schooling',
    y = 'Average Vaccination Rate'
)
chart + chart.transform_regression('Schooling', 'Average Vaccination Rate').mark_line()
# Out:
# <ipython-input-16-f63caac5da34>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   FactorHealth3 = FactorHealth2.groupby('Country')['Schooling', 'Average Vaccination Rate'].mean()
# alt.LayerChart(...)

# %%
#Comparing the mean average vaccination rate of every country
FactorHealth3.loc[:, ['Schooling', 'Average Vaccination Rate']].corr()
# Out:
#                           Schooling  Average Vaccination Rate
# Schooling                  1.000000                  0.641809
# Average Vaccination Rate   0.641809                  1.000000

# %%
#Animation of graphs
from IPython.display import HTML
from matplotlib.animation import FuncAnimation

#Filter data of specific year
def Year_data(Year, FactorHealth2):
  return FactorHealth2.loc[FactorHealth2['Year'] == Year]

#Function for data visualization
def interact_visualization1(Year, FactorHealth2):
  Visualization1 = Year_data(Year, FactorHealth2)
  ChartTotal1 = alt.Chart(Visualization1).mark_point().encode(x = 'Schooling', y = 'Average Vaccination Rate', color = 'Country')
  display(ChartTotal1)

#Update plot based on selected year and call the previous function
def Year_plot(year):
  interact_visualization1(year, FactorHealth2)

Year=FactorHealth2['Year'].unique()
widgets.interact_manual(Year_plot, year= Year)

#Function for animation
def animation(year):
  plt.clf() #only one plot per frame
  Chart2 = interact_visualization1(year, FactorHealth2)
  #Chart2.properties(width=600, height=400).interactive().show()

Animation = FuncAnimation(plt.gcf(), animation, frames= Year, interval=1000)
HTML(Animation.to_jshtml())
# Out:
# interactive(children=(Dropdown(description='year', options=(2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 20…
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
# ...

# %% [markdown]
# **Conclusion: (5 pt)**
# Summarise the work and the main findings related to the initial research question. *(5 pt)*
